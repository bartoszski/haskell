# %%
import plantrender

# %%
objects = """
object  ChannelsLocationsTables_df
ChannelsLocationsTables_df : act_name 
ChannelsLocationsTables_df : act_parameters 
ChannelsLocationsTables_df : chn_name 
ChannelsLocationsTables_df : database 
ChannelsLocationsTables_df : dbdesc_x 
ChannelsLocationsTables_df : dbdesc_y 
ChannelsLocationsTables_df : host 
ChannelsLocationsTables_df : loc_class 
ChannelsLocationsTables_df : loc_name 
ChannelsLocationsTables_df : tbl_base_name_cnt 
ChannelsLocationsTables_df : tbl_base_name_lst 
ChannelsLocationsTables_df : tbl_name_cnt 
ChannelsLocationsTables_df : tbl_name_lst 


object  ChannelsLocationsTables_pivoted_df
ChannelsLocationsTables_pivoted_df : CaptureChn_cnt 
ChannelsLocationsTables_pivoted_df : CaptureChn_lst 
ChannelsLocationsTables_pivoted_df : CaptureTables_cnt 
ChannelsLocationsTables_pivoted_df : CaptureTables_lst 
ChannelsLocationsTables_pivoted_df : IntegrateChn_cnt 
ChannelsLocationsTables_pivoted_df : IntegrateChn_lst 
ChannelsLocationsTables_pivoted_df : IntegrateTables_cnt 
ChannelsLocationsTables_pivoted_df : IntegrateTables_lst 
ChannelsLocationsTables_pivoted_df : database 
ChannelsLocationsTables_pivoted_df : host 
ChannelsLocationsTables_pivoted_df : loc_name 

object  ChannelsLocationsTables_pivoted_prd_df
ChannelsLocationsTables_pivoted_prd_df : CaptureChn_cnt 
ChannelsLocationsTables_pivoted_prd_df : CaptureChn_lst 
ChannelsLocationsTables_pivoted_prd_df : CaptureTables_cnt 
ChannelsLocationsTables_pivoted_prd_df : CaptureTables_lst 
ChannelsLocationsTables_pivoted_prd_df : IntegrateChn_cnt 
ChannelsLocationsTables_pivoted_prd_df : IntegrateChn_lst 
ChannelsLocationsTables_pivoted_prd_df : IntegrateTables_cnt 
ChannelsLocationsTables_pivoted_prd_df : IntegrateTables_lst 
ChannelsLocationsTables_pivoted_prd_df : database 
ChannelsLocationsTables_pivoted_prd_df : host 
ChannelsLocationsTables_pivoted_prd_df : loc_name 

object  Channelslocations_df
Channelslocations_df : act_name 
Channelslocations_df : act_parameters 
Channelslocations_df : chn_name 
Channelslocations_df : database 
Channelslocations_df : dbdesc 
Channelslocations_df : host 
Channelslocations_df : loc_class 
Channelslocations_df : loc_name 

object  Channelslocations_pivoted_df
Channelslocations_pivoted_df : Capture 
Channelslocations_pivoted_df : Integrate 
Channelslocations_pivoted_df : database 
Channelslocations_pivoted_df : host 
Channelslocations_pivoted_df : loc_name 


object  Channelslocations_pivoted_prd_df
Channelslocations_pivoted_prd_df : Capture 
Channelslocations_pivoted_prd_df : Integrate 
Channelslocations_pivoted_prd_df : database 
Channelslocations_pivoted_prd_df : host 
Channelslocations_pivoted_prd_df : loc_name 


object  Channelslocations_prd_df
Channelslocations_prd_df : act_name 
Channelslocations_prd_df : act_parameters 
Channelslocations_prd_df : chn_name 
Channelslocations_prd_df : database 
Channelslocations_prd_df : dbdesc 
Channelslocations_prd_df : host 
Channelslocations_prd_df : loc_class 
Channelslocations_prd_df : loc_name 


object  Table_agg_df
Table_agg_df : chn_name 
Table_agg_df : database 
Table_agg_df : dbdesc 
Table_agg_df : host 
Table_agg_df : tbl_base_name_cnt 
Table_agg_df : tbl_base_name_lst 
Table_agg_df : tbl_name_cnt 
Table_agg_df : tbl_name_lst 


object  Table_agg_prd_df
Table_agg_prd_df : chn_name 
Table_agg_prd_df : database 
Table_agg_prd_df : dbdesc 
Table_agg_prd_df : host 
Table_agg_prd_df : tbl_base_name_cnt 
Table_agg_prd_df : tbl_base_name_lst 
Table_agg_prd_df : tbl_name_cnt 
Table_agg_prd_df : tbl_name_lst 


object  locations_channels_tables_prd_df
locations_channels_tables_prd_df : CaptureChn_cnt 
locations_channels_tables_prd_df : CaptureChn_lst 
locations_channels_tables_prd_df : CaptureTables_cnt 
locations_channels_tables_prd_df : CaptureTables_lst 
locations_channels_tables_prd_df : IntegrateChn_cnt 
locations_channels_tables_prd_df : IntegrateChn_lst 
locations_channels_tables_prd_df : IntegrateTables_cnt 
locations_channels_tables_prd_df : IntegrateTables_lst 
locations_channels_tables_prd_df : database 
locations_channels_tables_prd_df : db_instance 
locations_channels_tables_prd_df : db_node_name 
locations_channels_tables_prd_df : dbdesc 
locations_channels_tables_prd_df : host 
locations_channels_tables_prd_df : loc_class 
locations_channels_tables_prd_df : loc_db_user 
locations_channels_tables_prd_df : loc_description 
locations_channels_tables_prd_df : loc_name 
locations_channels_tables_prd_df : loc_remote_login 
locations_channels_tables_prd_df : loc_remote_node 
locations_channels_tables_prd_df : loc_remote_port 

object  locations_df
locations_df : database 
locations_df : db_instance 
locations_df : db_node_name 
locations_df : dbdesc 
locations_df : host 
locations_df : loc_class 
locations_df : loc_db_user 
locations_df : loc_description 
locations_df : loc_name 
locations_df : loc_remote_login 
locations_df : loc_remote_node 
locations_df : loc_remote_port 

object  locations_prd_channels_df
locations_prd_channels_df : Capture 
locations_prd_channels_df : Integrate 
locations_prd_channels_df : database 
locations_prd_channels_df : db_instance 
locations_prd_channels_df : db_node_name 
locations_prd_channels_df : dbdesc 
locations_prd_channels_df : host 
locations_prd_channels_df : loc_class 
locations_prd_channels_df : loc_db_user 
locations_prd_channels_df : loc_description 
locations_prd_channels_df : loc_name 
locations_prd_channels_df : loc_remote_login 
locations_prd_channels_df : loc_remote_node 
locations_prd_channels_df : loc_remote_port 

object  locations_prd_df
locations_prd_df : database 
locations_prd_df : db_instance 
locations_prd_df : db_node_name 
locations_prd_df : dbdesc 
locations_prd_df : host 
locations_prd_df : loc_class 
locations_prd_df : loc_db_user 
locations_prd_df : loc_description 
locations_prd_df : loc_name 
locations_prd_df : loc_remote_login 
locations_prd_df : loc_remote_node 
locations_prd_df : loc_remote_port 

object source_lkp
"""

# %%
content ="""
@startuml

scale  800 height
left to right direction
"""+objects+"""

json LocationsParsed{}
json hvr_Table_Agg{}
json Channel2Location{}


LocationsParsed -d-> locations_df
locations_df    -d-> locations_prd_df

hvr_Table_Agg -d-> Table_agg_df
Table_agg_df  -d-> Table_agg_prd_df



Channel2Location -d-> Channelslocations_df 
Channelslocations_df -d-> Channelslocations_prd_df

Channelslocations_df -d-> ChannelsLocationsTables_df
Table_agg_df    -d-> ChannelsLocationsTables_df

ChannelsLocationsTables_df -d-> ChannelsLocationsTables_pivoted_df
ChannelsLocationsTables_pivoted_df -d-> ChannelsLocationsTables_pivoted_prd_df

Channelslocations_df  -d->  Channelslocations_pivoted_df     
Channelslocations_pivoted_df  -l->  Channelslocations_pivoted_prd_df

locations_prd_df  -d->  locations_prd_channels_df
Channelslocations_pivoted_prd_df  -d->  locations_prd_channels_df

locations_prd_df  -d->  locations_channels_tables_prd_df
ChannelsLocationsTables_pivoted_df  -d->   locations_channels_tables_prd_df


note left of ChannelsLocationsTables_pivoted_df
<color:orange>_d</color> logic added
end note


class “[Sources] Basic : Capture Sources + channel counts” as Report_Sources.001 
class “[Sources] Source Synonyms ” as Report_Sources.003


class “[channel] names homonyms” as Report_Channel.002 
class “[Locations] homonymns on db_node_name  & db_instancelevels of locations ” as Report_Locations.004

xlsx.source_lkp -d-> source_lkp 
source_lkp -d-> Report_Sources.001
locations_channels_tables_prd_df -d-> Report_Sources.001

object infra_lkp
xlsx.infra_lkp -d-> infra_lkp
Channelslocations_prd_df -d-> Report_Channel.002
infra_lkp -d-> Report_Channel.002

locations_prd_df -d-> Report_Sources.003
locations_prd_df -d-> Report_Locations.004


@enduml
"""

plantrender.render(content)

# %%
content= """
@startuml 
object “ [Sources] Basic : Capture Sources + channel counts” as report1 

@enduml
"""
plantrender.render(content)

# %% [markdown]
# content = """
# @startuml
# digraph foo {
#     size="15,";
#     rankdir="LR"; // Set orientation to left to right
#     node [shape=record];
#
# ChannelsLocationsTables_df [label="{ { ChannelsLocationsTables_df }|{act_name|act_parameters|chn_name|database|dbdesc_x|dbdesc_y|host|loc_class|loc_name|tbl_base_name_cnt|tbl_base_name_lst|tbl_name_cnt|tbl_name_lst|}}"]
# ChannelsLocationsTables_pivoted_df [label="{ { ChannelsLocationsTables_pivoted_df }|{CaptureChn_cnt|CaptureTables_cnt|CaptureTables_lst|IntegrateChn_cnt|IntegrateTables_cnt|IntegrateTables_lst|database|host|loc_name|}}"]
# ChannelsLocationsTables_pivoted_prd_df [label="{ { ChannelsLocationsTables_pivoted_prd_df }|{CaptureChn_cnt|CaptureTables_cnt|CaptureTables_lst|IntegrateChn_cnt|IntegrateTables_cnt|IntegrateTables_lst|database|host|loc_name|}}"]
# Channelslocations_df [label="{ { Channelslocations_df }|{act_name|act_parameters|chn_name|database|dbdesc|host|loc_class|loc_name|}}"]
# Channelslocations_pivoted_df [label="{ { Channelslocations_pivoted_df }|{Capture|Integrate|database|host|loc_name|}}"]
# Channelslocations_pivoted_prd_df [label="{ { Channelslocations_pivoted_prd_df }|{Capture|Integrate|database|host|loc_name|}}"]
# Channelslocations_prd_df [label="{ { Channelslocations_prd_df }|{act_name|act_parameters|chn_name|database|dbdesc|host|loc_class|loc_name|}}"]
# Table_agg_df [label="{ { Table_agg_df }|{chn_name|database|dbdesc|host|tbl_base_name_cnt|tbl_base_name_lst|tbl_name_cnt|tbl_name_lst|}}"]
# Table_agg_prd_df [label="{ { Table_agg_prd_df }|{chn_name|database|dbdesc|host|tbl_base_name_cnt|tbl_base_name_lst|tbl_name_cnt|tbl_name_lst|}}"]
#
# locations_channels_tables_prd_df [label="{ { locations_channels_tables_prd_df }|{CaptureChn_cnt|CaptureTables_cnt|CaptureTables_lst|IntegrateChn_cnt|IntegrateTables_cnt|IntegrateTables_lst|database|db_instance|db_node_name|dbdesc|host|loc_class|loc_db_user|loc_description|loc_name|loc_remote_login|loc_remote_node|loc_remote_port|}}"]
# locations_df [label="{ { locations_df }|{database|db_instance|db_node_name|dbdesc|host|loc_class|loc_db_user|loc_description|loc_name|loc_remote_login|loc_remote_node|loc_remote_port|}}"]
# locations_prd_channels_df [label="{ { locations_prd_channels_df }|{Capture|Integrate|database|db_instance|db_node_name|dbdesc|host|loc_class|loc_db_user|loc_description|loc_name|loc_remote_login|loc_remote_node|loc_remote_port|}}"]
# locations_prd_df [label="{ { locations_prd_df }|{database|db_instance|db_node_name|dbdesc|host|loc_class|loc_db_user|loc_description|loc_name|loc_remote_login|loc_remote_node|loc_remote_port|}}"]
# LocationsParsed -> locations_df
# locations_df    -> locations_prd_df
#
# hvr_Table_Agg -> Table_agg_df
# Table_agg_df  -> Table_agg_prd_df
#
# Channel2Location -> Channelslocations_df
# Channelslocations_df -> Channelslocations_prd_df
#
# Channelslocations_df -> ChannelsLocationsTables_df
# Table_agg_df    -> ChannelsLocationsTables_df
#
# ChannelsLocationsTables_df -> ChannelsLocationsTables_pivoted_df
# ChannelsLocationsTables_pivoted_df->ChannelsLocationsTables_pivoted_prd_df
#
# Channelslocations_df -> Channelslocations_pivoted_df
# Channelslocations_pivoted_df -> Channelslocations_pivoted_prd_df
#
# locations_prd_df -> locations_prd_channels_df
# Channelslocations_pivoted_prd_df -> locations_prd_channels_df
#
# locations_prd_df -> locations_channels_tables_prd_df
# ChannelsLocationsTables_pivoted_df ->  locations_channels_tables_prd_df
#
# _d -> ChannelsLocationsTables_pivoted_df
#
# }
#
# @enduml
#
# """
#
# plantrender.render(content)
